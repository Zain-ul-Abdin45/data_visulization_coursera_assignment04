# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib notebook
plt.style.use('seaborn')

# %%
mean = pd.read_csv('mean.csv')
mean.head()
# Out:
#    Unnamed: 0  YEAR  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0           0  1901   24.23    18.71    26.06    27.30    21.92
# 1           1  1902   24.33    19.70    26.44    27.18    21.49
# 2           2  1903   23.80    19.05    25.47    27.17    21.27
# 3           3  1904   23.86    18.66    25.84    26.83    21.43
# 4           4  1905   23.71    17.58    24.99    27.37    21.48

# %%
minimum = pd.read_csv('minimum.csv')
minimum.head()
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  13.58  14.72  17.91  20.93  23.18  24.05  23.82  23.58
# 1           1  1902  13.08  14.20  18.44  21.30  23.63  23.97  23.68  23.34
# 2           2  1903  13.20  14.55  17.12  20.67  22.95  23.85  23.53  23.29
# 3           3  1904  13.04  14.07  17.70  21.42  23.02  23.64  23.35  23.03
# 4           4  1905  12.83  12.74  16.88  19.62  23.32  24.13  23.93  24.31
#
#      SEP    OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  22.09  20.20  16.16  13.41   19.51    14.16    20.67    23.38    16.59
# 1  22.11  19.63  16.35  13.53   19.44    13.64    21.12    23.28    16.50
# 2  22.84  20.12  15.84  12.93   19.25    13.87    20.25    23.40    16.29
# 3  21.65  19.50  15.77  14.06   19.22    13.72    20.72    22.96    16.44
# 4  22.47  21.65  16.63  13.59   19.03    12.81    19.97    23.43    16.39

# %%
rainfall = pd.read_csv('rainfall.csv')
rainfall.head()
# Out:
#    Unnamed: 0  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL    AUG    SEP  \
# 0           0  1901  34.7  38.6  17.8  38.9  50.6  113.2  241.4  271.6  124.7
# 1           1  1902   7.4   4.2  19.0  44.1  48.8  111.7  284.9  201.0  200.2
# 2           2  1903  16.7   8.0  31.1  17.1  59.5  120.3  293.2  274.0  198.1
# 3           3  1904  14.9   9.7  31.4  33.7  73.8  165.5  260.3  207.7  130.8
# 4           4  1905  24.7  20.3  41.8  33.8  55.8   93.7  253.0  201.7  178.1
#
#      OCT   NOV   DEC     ANN  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# 0   52.4  38.7   8.2  1030.8     73.2    107.3    751.0     99.3
# 1   62.5  29.4  25.2  1038.4     11.6    111.9    797.8    117.2
# 2  119.5  40.3  18.0  1195.9     24.7    107.7    885.6    177.8
# 3   69.8  11.2  16.4  1025.1     24.5    138.8    764.3     97.4
# 4   54.9   9.6  10.1   977.5     45.0    131.4    726.4     74.7

# %%
weather = pd.DataFrame(mean['YEAR'])
weather['Mean'] = mean['ANNUAL']
weather.head()
# Out:
#    YEAR   Mean
# 0  1901  24.23
# 1  1902  24.33
# 2  1903  23.80
# 3  1904  23.86
# 4  1905  23.71

# %%
weather['Minimum'] = minimum['ANNUAL']
weather.head()
# Out:
#    YEAR   Mean  Minimum
# 0  1901  24.23    19.51
# 1  1902  24.33    19.44
# 2  1903  23.80    19.25
# 3  1904  23.86    19.22
# 4  1905  23.71    19.03

# %%
filt = rainfall['YEAR'] <= 2012
weather['Rainfall'] = rainfall.loc[filt, 'ANN'] / 100
weather = weather[weather['YEAR'] > 1980]
weather = weather.set_index('YEAR')
weather.head()
# Out:
#        Mean  Minimum  Rainfall
# YEAR
# 1981  24.27    19.25    11.707
# 1982  24.15    19.21    10.844
# 1983  24.12    19.14    13.209
# 1984  24.26    19.25    11.608
# 1985  24.45    19.30    11.449

# %%
x = weather.index.tolist()
y1 = weather['Mean'].tolist()
y2 = weather['Minimum'].tolist()
y3 = weather['Rainfall'].tolist()

plt.xticks(x, rotation=40)
plt.tick_params(axis="x", labelsize=8)

plt.plot(x, y1, '-s', label = "Mean Temperature ($\,^{\circ}\mathrm{C}$)",color='b')
plt.plot(x, y2, '-o', label = "Minimum Temperature ($\,^{\circ}\mathrm{C}$)",color='brown')
plt.plot(x, y3, '-*', label = "Rainfall (0.1cm)",color='green')

plt.xlabel("Years")
plt.ylabel("")
plt.title('Average Mean and Minimum Temperatures in India(1981-2012) (in $\,^{\circ}\mathrm{C}$) and Rainfall')
 
plt.legend(loc="best")
# Out:
# <img src="data:image/png;base64,..." width="800">
